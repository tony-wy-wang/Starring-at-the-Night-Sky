# %%
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from PIL import Image
from torch.optim import lr_scheduler
import copy
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np
import torch.optim as optim
import random
import torch.nn as nn
import torch.nn.functional as F
import pprint, pickle
from torchvision import datasets, models, transforms
import time
import torch
import torchvision
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
from torchvision.datasets import DatasetFolder
from PIL import Image
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms
import time
import os
import copy

# %%
def npy_loader(path):
    sample = torch.from_numpy(np.load(path))
    return sample
class npyLoader(DatasetFolder):
    def __init__(self, txt, transform=None, target_transform=None, loader=npy_loader):
        fh = open(txt, 'r')
        imgs = []
        for line in fh:
            line = line.strip('\n')
            line = line.rstrip()
            words = line.split()
            if str(words[1]) == "i":
                label = 0
            elif str(words[1]) == "o":
                label = 1
            elif str(words[1]) == "u":
                label = 2
            else:
                label = 3
            imgs.append((words[0],str(label)))

        self.imgs = imgs
        self.transform = transform
        self.target_transform = target_transform
        self.loader = loader

# %%
"""
i:166 (* 8)
o:82  (*16)
p:1330
u:83  (*16)
""" 
def default_loader(path):
    data1 = np.load(path)
    data1 = np.log(data1)
    return data1

class MyDataset(Dataset):
    def __init__(self, txt,loader=default_loader, transform=None, target_transform=None):
        fh = open(txt, 'r')
        imgs = []
        for line in fh:
            line = line.strip('\n')
            line = line.rstrip()
            words = line.split()
            if str(words[1]) == "i":
                label = 0
            elif str(words[1]) == "o":
                label = 1
            elif str(words[1]) == "u":
                label = 2
            else:
                label = 3
            imgs.append((words[0],str(label)))

        self.imgs = imgs
        self.transform = transform
        self.target_transform = target_transform
        self.loader = loader

    def __getitem__(self, index):
        fn, label = self.imgs[index]
        img = self.loader(fn)
        img = img[256+128:768-128,256+128:768-128,:]#crop the cernter part of the image
        if self.transform is not None:
            img = self.transform(img)
        img=img.swapaxes(1,2)
        img=img.swapaxes(0,1)
        img = torch.from_numpy(img)
        label = list(map(int, label))
        label = np.asarray(label)
        label = label.astype(int)
        label = torch.from_numpy(label)
        return img,label

    def __len__(self):
        return len(self.imgs)

# %%
data_transforms = {
    'train': transforms.Compose([
#         transforms.CenterCrop(224),
#         transforms.RandomHorizontalFlip(),
#         transforms.ToTensor(),
#         transforms.Normalize(mean = [0.5]*30, std = [0.5]*30)
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
#         transforms.ToTensor(),
#         transforms.Normalize(mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5))
#         transforms.Resize(256),
#         transforms.CenterCrop(224),
#         transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
#         transforms.ToTensor(),
#         transforms.Normalize(mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5))
#         transforms.Resize(256),
#         transforms.CenterCrop(224),
#         transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

trainset = MyDataset(txt='E:\\TMT_SITE_RAID\\TMT_DATA_2\\T2-Armazones\\Test_Data\\list1.txt',transform=data_transforms['train'])

train_size = 0.70
val_size = 0.20
test_size = 0.10
num_train = len(trainset)
indices = list(range(num_train))
random.shuffle(indices)
split = int(np.floor(train_size * num_train))
split_val = int(np.floor(val_size * num_train))

train_idx, valid_idx, test_idx = indices[:split], indices[split:split_val+split], indices[split_val+split:]

image_datasets={'train': MyDataset(txt='E:\\TMT_SITE_RAID\\TMT_DATA_2\\T2-Armazones\\Test_Data\\list1.txt',  transform=data_transforms['train']),
                'val': MyDataset(txt='E:\\TMT_SITE_RAID\\TMT_DATA_2\\T2-Armazones\\Test_Data\\list1.txt',  transform=data_transforms['val']),
                'test': MyDataset(txt='E:\\TMT_SITE_RAID\\TMT_DATA_2\\T2-Armazones\\Test_Data\\list1.txt',  transform=data_transforms['test']),
                }
train_sampler = torch.utils.data.sampler.RandomSampler(train_idx)
val_sampler = torch.utils.data.sampler.RandomSampler(valid_idx)
test_sampler = torch.utils.data.sampler.RandomSampler(test_idx)

dataloaders = {
        'train': torch.utils.data.DataLoader(trainset, batch_size=4,sampler = train_sampler,
                                          shuffle=False, num_workers=0),
        'val': torch.utils.data.DataLoader(trainset, batch_size=4,sampler = val_sampler,
                                          shuffle=False, num_workers=0),
        'test': torch.utils.data.DataLoader(trainset, batch_size=1,sampler = test_sampler,
                                          shuffle=False, num_workers=0),
                }
dataset_sizes = {
        'train':num_train* train_size,
        'val': num_train* val_size,
        'test': num_train * test_size
				    }

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
inputs, classes = next(iter(dataloaders['train']))
# plt.matshow(np.log(inputs[3,0,:,:]))
plt.matshow(inputs[3,0,:,:])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    def __init__(self, inchannel, outchannel, stride=1):
        super(ResidualBlock, self).__init__()
        self.left = nn.Sequential(
            nn.Conv2d(inchannel, outchannel, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(outchannel),
            nn.ReLU(inplace=True),
            nn.Conv2d(outchannel, outchannel, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(outchannel)
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or inchannel != outchannel:
            self.shortcut = nn.Sequential(
                nn.Conv2d(inchannel, outchannel, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(outchannel)
            )

    def forward(self, x):
        out = self.left(x)
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet(nn.Module):
    def __init__(self, ResidualBlock, num_classes=4):
        super(ResNet, self).__init__()
        self.inchannel = 64
        #change the channel to 30
        self.conv1 = nn.Sequential(
            nn.Conv2d(30, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
        )
        self.layer1 = self.make_layer(ResidualBlock, 64,  2, stride=1)
        self.layer2 = self.make_layer(ResidualBlock, 128, 2, stride=2)
        self.layer3 = self.make_layer(ResidualBlock, 256, 2, stride=2)
        self.layer4 = self.make_layer(ResidualBlock, 512, 2, stride=2)
        self.fc = nn.Linear(32768, num_classes)

    def make_layer(self, block, channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)   #strides=[1,1]
        layers = []
        for stride in strides:
            layers.append(block(self.inchannel, channels, stride))
            self.inchannel = channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out


def ResNet18():

    return ResNet(ResidualBlock)
net = ResNet18()
use_gpu = torch.cuda.is_available()  # 
if use_gpu:
    net = net.cuda()
epc = 100
criterion = nn.CrossEntropyLoss()
#optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
optimizer = optim.Adam(net.parameters(), lr = 0.001, betas=(0.9, 0.999))
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
trainloader = dataloaders['train']
valloader = dataloaders['val']
EPOCH = 135   #total epoches
pre_epoch = 0  # epoches existed
LR = 0.1

# %%
epc = 100
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
accuracy_T = np.zeros(epc)
accuracy = np.zeros(epc)
j = 0
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
trainloader = dataloaders['train']
testloader = dataloaders['val']
# EPOCH = 135   #total epoches
pre_epoch = 0  # epoches existed
LR = 0.1       
n_val_samples = 4870 * 0.2
for epoch in range(epc):  # loop over the dataset multiple times
    correct = 0.0
    total = 0.0
    running_loss = 0.0
    running_loss_V = 0.0
    correct_T = 0.0
    total_T = 0.0
    
    running_loss = 0.0
    print('Current epoch:',epoch)
    for i, data in enumerate(dataloaders['train'], 0):
        # get the inputs
        inputs, labels = data
        inputs = inputs.type(torch.FloatTensor)
        inputs = inputs.cuda()
        labels = labels.type(torch.FloatTensor)
        labels = labels.cuda()
#         print(inputs.size())
#         inputs, labels = inputs.cuda(), labels.cuda()
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward + backward + optimize
        outputs = net(inputs)
#         print(outputs)
        _, predicted = torch.max(outputs.data, 1)
#         labels = labels.view(-1,4)

        labels = labels.long()
        correct_T += (predicted == labels).sum().item()/4
        
        total_T += labels.size(0)
        accuracy_T[epoch] = 100 * correct_T / total_T
        print('correct_t:',correct_T,total_T)
        print((predicted == labels).sum().item()/4)
        print(predicted)
        print(labels)
        loss = criterion(outputs, labels.view(labels.size(1), -1)[0])
        loss.backward()
        optimizer.step()
        
        # print statistics
        running_loss += loss.item()
        if i % 200== 199:    # print every 200 mini-batches
            print('[%d, %5d] training loss: %.3f training accuracy: %.2f' %
                  (epoch + 1, i + 1, running_loss /  200, accuracy_T[epoch]))
            for data in valloader:
                images, labels = data
                images = images.type(torch.FloatTensor)
                images = images.cuda()
                labels = labels.type(torch.FloatTensor)
                labels = labels.cuda()
                
              
                outputs = net(images)
                
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                labels = labels.long()
                #print(total ,'   ', correct)
                correct += (predicted == labels).sum().item()
                accuracy[epoch] = 100 * correct / total
                loss = criterion(outputs, labels.view(labels.size(1), -1)[0])
                running_loss_V += loss.item()
            loss_mat[epoch] = running_loss / 200
            loss_V[epoch] = running_loss_V / (n_val_samples/4)
            print('Validation loss: %.3f validation accuracy: %.2f' %
                (loss_V[epoch] , accuracy[epoch]))
            running_loss = 0.0
            running_loss_V = 0.0
            correct = 0
            total = 0

print('Finished Training')
# Out:
# Current epoch: 0
# correct_t: 0.0 4.0
# 0.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1.0 8.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 3.0 12.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 5.5 16.0
# 2.5
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 6.5 20.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 7.5 24.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 8.5 28.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 8.5 32.0
# 0.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 9.5 36.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 9.5 40.0
# 0.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 10.75 44.0
# 1.25
# tensor([1, 1, 1, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 10.75 48.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 12.75 52.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 15.75 56.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 18.75 60.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 18.75 64.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 20.75 68.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 21.75 72.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 24.75 76.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 27.75 80.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 29.75 84.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 31.75 88.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 32.75 92.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 34.75 96.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 36.75 100.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 36.75 104.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 38.75 108.0
# 2.0
# tensor([0, 1, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 40.5 112.0
# 1.75
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 40.5 116.0
# 0.0
# tensor([1, 1, 1, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 41.0 120.0
# 0.5
# tensor([0, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 42.25 124.0
# 1.25
# tensor([1, 1, 1, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 42.75 128.0
# 0.5
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 44.75 132.0
# 2.0
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 46.5 136.0
# 1.75
# tensor([0, 0, 3, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 47.5 140.0
# 1.0
# tensor([3, 0, 3, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 49.25 144.0
# 1.75
# tensor([3, 3, 0, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 51.25 148.0
# 2.0
# tensor([3, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 52.25 152.0
# 1.0
# tensor([3, 0, 0, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 53.75 156.0
# 1.5
# tensor([0, 0, 3, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 55.5 160.0
# 1.75
# tensor([0, 0, 0, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 55.5 164.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 57.5 168.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 60.5 172.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 60.5 176.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 61.5 180.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 62.5 184.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 64.5 188.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 65.5 192.0
# 1.0
# tensor([1, 1, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 66.5 196.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 68.5 200.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 70.5 204.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 71.5 208.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 73.5 212.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 74.5 216.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 77.5 220.0
# 3.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 79.5 224.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 80.5 228.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 81.5 232.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 85.5 236.0
# 4.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 87.5 240.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 89.5 244.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 89.5 248.0
# 0.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 92.5 252.0
# 3.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 96.5 256.0
# 4.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 99.5 260.0
# 3.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 102.5 264.0
# 3.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 102.5 268.0
# 0.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 105.5 272.0
# 3.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 106.5 276.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 108.5 280.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 109.5 284.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 109.5 288.0
# 0.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 111.5 292.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 113.5 296.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 114.5 300.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 116.0 304.0
# 1.5
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 117.0 308.0
# 1.0
# tensor([0, 1, 0, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 118.0 312.0
# 1.0
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 119.5 316.0
# 1.5
# tensor([1, 0, 1, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 120.5 320.0
# 1.0
# tensor([3, 3, 1, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 122.0 324.0
# 1.5
# tensor([1, 0, 3, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 123.25 328.0
# 1.25
# tensor([3, 1, 3, 3], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 123.75 332.0
# 0.5
# tensor([1, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 124.0 336.0
# 0.25
# tensor([1, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 125.5 340.0
# 1.5
# tensor([3, 1, 3, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 127.0 344.0
# 1.5
# tensor([3, 3, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 128.0 348.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 130.0 352.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 131.0 356.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 132.0 360.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 133.5 364.0
# 1.5
# tensor([0, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 134.75 368.0
# 1.25
# tensor([0, 0, 1, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 136.25 372.0
# 1.5
# tensor([1, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 137.25 376.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 137.25 380.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 138.25 384.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 139.25 388.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 141.25 392.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 142.25 396.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 143.25 400.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 143.25 404.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 145.25 408.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 147.25 412.0
# 2.0
# tensor([0, 1, 0, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 147.25 416.0
# 0.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 148.25 420.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 150.25 424.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 151.25 428.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 153.25 432.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 154.25 436.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 158.25 440.0
# 4.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 160.25 444.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 160.25 448.0
# 0.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 163.25 452.0
# 3.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 166.25 456.0
# 3.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 167.25 460.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 169.25 464.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 170.25 468.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 171.25 472.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 173.25 476.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 173.25 480.0
# 0.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 174.25 484.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 176.25 488.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 178.25 492.0
# 2.0
# tensor([0, 1, 0, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 180.25 496.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 180.25 500.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 182.25 504.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 183.25 508.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 184.25 512.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 186.25 516.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 190.25 520.0
# 4.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 192.25 524.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 193.25 528.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 194.25 532.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 196.25 536.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 198.25 540.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 198.25 544.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 200.25 548.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 200.25 552.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 203.25 556.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 204.25 560.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 205.25 564.0
# 1.0
# tensor([0, 1, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 206.75 568.0
# 1.5
# tensor([0, 1, 1, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 208.75 572.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 210.0 576.0
# 1.25
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 211.0 580.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 212.0 584.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 213.0 588.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 216.0 592.0
# 3.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 218.0 596.0
# 2.0
# tensor([0, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 219.0 600.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 220.0 604.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 220.5 608.0
# 0.5
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 221.75 612.0
# 1.25
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 222.75 616.0
# 1.0
# tensor([0, 0, 1, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 223.25 620.0
# 0.5
# tensor([0, 0, 1, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 225.25 624.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 225.25 628.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 228.25 632.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 229.25 636.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 232.25 640.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 233.25 644.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 234.25 648.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 237.25 652.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 238.25 656.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 238.25 660.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 240.25 664.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 240.25 668.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 242.25 672.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 245.25 676.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 247.25 680.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 249.25 684.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 251.25 688.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 252.25 692.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 255.25 696.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 257.25 700.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 257.25 704.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 258.25 708.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 260.25 712.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 262.25 716.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 262.25 720.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 264.25 724.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 264.25 728.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 265.25 732.0
# 1.0
# tensor([0, 0, 0, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 266.0 736.0
# 0.75
# tensor([0, 1, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 266.5 740.0
# 0.5
# tensor([3, 1, 3, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 269.5 744.0
# 3.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 269.5 748.0
# 0.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 269.5 752.0
# 0.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 270.5 756.0
# 1.0
# tensor([1, 1, 3, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 271.5 760.0
# 1.0
# tensor([1, 3, 3, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 273.75 764.0
# 2.25
# tensor([3, 1, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 274.75 768.0
# 1.0
# tensor([3, 3, 3, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 278.75 772.0
# 4.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 280.75 776.0
# 2.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 281.75 780.0
# 1.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 282.75 784.0
# 1.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 283.75 788.0
# 1.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 285.75 792.0
# 2.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 285.75 796.0
# 0.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 286.75 800.0
# 1.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# [1,   200] training loss: 1.144 training accuracy: 35.84
# Validation loss: 0.990 validation accuracy: 2.05
# correct_t: 287.75 804.0
# 1.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 289.25 808.0
# 1.5
# tensor([3, 0, 0, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 292.25 812.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 294.25 816.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 295.25 820.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 296.25 824.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 297.25 828.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 299.25 832.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 299.25 836.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 299.25 840.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 300.25 844.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 301.25 848.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 303.25 852.0
# 2.0
# tensor([1, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 305.25 856.0
# 2.0
# tensor([1, 0, 1, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 305.25 860.0
# 0.0
# tensor([1, 1, 1, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 307.75 864.0
# 2.5
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 310.25 868.0
# 2.5
# tensor([0, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 312.5 872.0
# 2.25
# tensor([0, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 315.0 876.0
# 2.5
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 317.0 880.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 319.0 884.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 320.0 888.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 322.0 892.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 323.0 896.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 326.0 900.0
# 3.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 328.0 904.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 329.0 908.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 329.0 912.0
# 0.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 330.0 916.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 333.0 920.0
# 3.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 334.0 924.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 335.0 928.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 335.0 932.0
# 0.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 336.75 936.0
# 1.75
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 338.25 940.0
# 1.5
# tensor([3, 1, 3, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 339.25 944.0
# 1.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 339.25 948.0
# 0.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 340.0 952.0
# 0.75
# tensor([3, 3, 3, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 340.75 956.0
# 0.75
# tensor([0, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 342.25 960.0
# 1.5
# tensor([3, 0, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 344.5 964.0
# 2.25
# tensor([0, 0, 3, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 345.5 968.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 348.5 972.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 349.5 976.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 350.5 980.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 351.5 984.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 353.5 988.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 356.5 992.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 360.5 996.0
# 4.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 361.5 1000.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 364.5 1004.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 364.5 1008.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 366.5 1012.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 368.5 1016.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 369.5 1020.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 369.5 1024.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 372.5 1028.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 374.25 1032.0
# 1.75
# tensor([0, 0, 0, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 376.25 1036.0
# 2.0
# tensor([1, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 377.25 1040.0
# 1.0
# tensor([0, 0, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 379.25 1044.0
# 2.0
# tensor([0, 0, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 380.25 1048.0
# 1.0
# tensor([1, 0, 0, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 382.0 1052.0
# 1.75
# tensor([0, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 383.25 1056.0
# 1.25
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 384.5 1060.0
# 1.25
# tensor([0, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 387.0 1064.0
# 2.5
# tensor([0, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 388.0 1068.0
# 1.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 389.0 1072.0
# 1.0
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 390.0 1076.0
# 1.0
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 391.75 1080.0
# 1.75
# tensor([0, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 393.5 1084.0
# 1.75
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 394.5 1088.0
# 1.0
# tensor([0, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 396.25 1092.0
# 1.75
# tensor([1, 1, 1, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 397.5 1096.0
# 1.25
# tensor([1, 1, 0, 3], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 399.5 1100.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 400.0 1104.0
# 0.5
# tensor([1, 3, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 401.5 1108.0
# 1.5
# tensor([3, 3, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 403.5 1112.0
# 2.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 404.5 1116.0
# 1.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 404.5 1120.0
# 0.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 405.5 1124.0
# 1.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 406.5 1128.0
# 1.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 407.5 1132.0
# 1.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 408.5 1136.0
# 1.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 409.5 1140.0
# 1.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 409.5 1144.0
# 0.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 411.0 1148.0
# 1.5
# tensor([3, 3, 1, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 412.0 1152.0
# 1.0
# tensor([1, 3, 1, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 413.25 1156.0
# 1.25
# tensor([0, 3, 3, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 414.25 1160.0
# 1.0
# tensor([0, 1, 1, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 415.75 1164.0
# 1.5
# tensor([1, 1, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 417.25 1168.0
# 1.5
# tensor([0, 0, 1, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 417.75 1172.0
# 0.5
# tensor([1, 0, 1, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 419.75 1176.0
# 2.0
# tensor([1, 0, 0, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 421.25 1180.0
# 1.5
# tensor([1, 1, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 422.0 1184.0
# 0.75
# tensor([0, 1, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 423.0 1188.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 425.0 1192.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 428.0 1196.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 430.0 1200.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 433.0 1204.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 436.0 1208.0
# 3.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 437.0 1212.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 438.0 1216.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 439.0 1220.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 441.0 1224.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 443.0 1228.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 443.0 1232.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 445.0 1236.0
# 2.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 446.0 1240.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 447.0 1244.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 448.25 1248.0
# 1.25
# tensor([0, 0, 0, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 449.5 1252.0
# 1.25
# tensor([0, 1, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 451.0 1256.0
# 1.5
# tensor([1, 1, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 452.0 1260.0
# 1.0
# tensor([0, 0, 1, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 453.0 1264.0
# 1.0
# tensor([0, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 454.0 1268.0
# 1.0
# tensor([1, 0, 1, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 455.5 1272.0
# 1.5
# tensor([0, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 457.0 1276.0
# 1.5
# tensor([0, 1, 0, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 458.0 1280.0
# 1.0
# tensor([3, 3, 1, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 459.5 1284.0
# 1.5
# tensor([1, 1, 3, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 461.0 1288.0
# 1.5
# tensor([1, 1, 3, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 461.25 1292.0
# 0.25
# tensor([1, 3, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 462.25 1296.0
# 1.0
# tensor([3, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 464.25 1300.0
# 2.0
# tensor([3, 1, 1, 3], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 465.75 1304.0
# 1.5
# tensor([1, 1, 3, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 467.0 1308.0
# 1.25
# tensor([3, 1, 3, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 468.5 1312.0
# 1.5
# tensor([1, 3, 3, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 468.75 1316.0
# 0.25
# tensor([3, 1, 3, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 470.75 1320.0
# 2.0
# tensor([1, 1, 3, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 472.25 1324.0
# 1.5
# tensor([1, 3, 1, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 473.5 1328.0
# 1.25
# tensor([3, 3, 1, 3], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 475.25 1332.0
# 1.75
# tensor([3, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 475.75 1336.0
# 0.5
# tensor([3, 1, 1, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 477.75 1340.0
# 2.0
# tensor([1, 3, 1, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 478.25 1344.0
# 0.5
# tensor([1, 3, 3, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 480.5 1348.0
# 2.25
# tensor([1, 3, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 481.25 1352.0
# 0.75
# tensor([1, 1, 1, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 483.5 1356.0
# 2.25
# tensor([1, 1, 3, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 485.25 1360.0
# 1.75
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 486.75 1364.0
# 1.5
# tensor([3, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 488.75 1368.0
# 2.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 490.0 1372.0
# 1.25
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 492.0 1376.0
# 2.0
# tensor([1, 1, 1, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 492.5 1380.0
# 0.5
# tensor([1, 1, 1, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 492.75 1384.0
# 0.25
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 494.25 1388.0
# 1.5
# tensor([1, 1, 1, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 496.25 1392.0
# 2.0
# tensor([1, 0, 1, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 497.25 1396.0
# 1.0
# tensor([1, 1, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 498.5 1400.0
# 1.25
# tensor([1, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 501.0 1404.0
# 2.5
# tensor([1, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 502.0 1408.0
# 1.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 502.0 1412.0
# 0.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# ...
# correct_t: 1502.25 3016.0
# 2.0
# tensor([1, 1, 3, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 1504.25 3020.0
# 2.0
# tensor([3, 0, 0, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1505.75 3024.0
# 1.5
# tensor([1, 0, 3, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 1507.75 3028.0
# 2.0
# tensor([0, 3, 0, 3], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1509.0 3032.0
# 1.25
# tensor([3, 0, 1, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 1510.5 3036.0
# 1.5
# tensor([1, 3, 0, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 1514.5 3040.0
# 4.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 1516.0 3044.0
# 1.5
# tensor([0, 1, 3, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 1517.5 3048.0
# 1.5
# tensor([1, 0, 3, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 1520.0 3052.0
# 2.5
# tensor([3, 3, 0, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1522.5 3056.0
# 2.5
# tensor([0, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 1524.5 3060.0
# 2.0
# tensor([0, 0, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 1528.5 3064.0
# 4.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 1530.5 3068.0
# 2.0
# tensor([1, 0, 0, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1532.5 3072.0
# 2.0
# tensor([3, 3, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 1535.0 3076.0
# 2.5
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1536.5 3080.0
# 1.5
# tensor([3, 0, 1, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 1538.5 3084.0
# 2.0
# tensor([1, 0, 1, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 1540.0 3088.0
# 1.5
# tensor([1, 3, 0, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1542.0 3092.0
# 2.0
# tensor([0, 1, 1, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 1544.5 3096.0
# 2.5
# tensor([0, 0, 0, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1547.0 3100.0
# 2.5
# tensor([1, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 1549.5 3104.0
# 2.5
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 1551.5 3108.0
# 2.0
# tensor([1, 0, 0, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1554.0 3112.0
# 2.5
# tensor([0, 0, 0, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1556.0 3116.0
# 2.0
# tensor([3, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 1557.5 3120.0
# 1.5
# tensor([1, 3, 0, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1560.0 3124.0
# 2.5
# tensor([1, 1, 1, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 1562.0 3128.0
# 2.0
# tensor([1, 0, 0, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1563.5 3132.0
# 1.5
# tensor([1, 1, 0, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1565.0 3136.0
# 1.5
# tensor([1, 0, 3, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 1569.0 3140.0
# 4.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 1570.5 3144.0
# 1.5
# tensor([3, 1, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 1573.0 3148.0
# 2.5
# tensor([3, 3, 0, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1577.0 3152.0
# 4.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 1579.0 3156.0
# 2.0
# tensor([1, 3, 1, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 1580.75 3160.0
# 1.75
# tensor([3, 0, 3, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 1583.25 3164.0
# 2.5
# tensor([3, 3, 3, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 1587.25 3168.0
# 4.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 1589.75 3172.0
# 2.5
# tensor([1, 3, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 1592.25 3176.0
# 2.5
# tensor([1, 3, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 1594.75 3180.0
# 2.5
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1597.75 3184.0
# 3.0
# tensor([3, 1, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 1599.25 3188.0
# 1.5
# tensor([3, 0, 1, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 1600.75 3192.0
# 1.5
# tensor([3, 0, 0, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1602.25 3196.0
# 1.5
# tensor([0, 0, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 1603.75 3200.0
# 1.5
# tensor([1, 0, 3, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# [16,   800] training loss: 0.031 training accuracy: 50.12
# Validation loss: 0.009 validation accuracy: 399.18
# correct_t: 1605.75 3204.0
# 2.0
# tensor([1, 1, 0, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 1608.25 3208.0
# 2.5
# tensor([3, 3, 0, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1612.25 3212.0
# 4.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 1613.75 3216.0
# 1.5
# tensor([0, 3, 0, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1616.25 3220.0
# 2.5
# tensor([1, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 1618.75 3224.0
# 2.5
# tensor([1, 1, 1, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 1621.25 3228.0
# 2.5
# tensor([1, 1, 1, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 1623.25 3232.0
# 2.0
# tensor([1, 0, 1, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 1624.75 3236.0
# 1.5
# tensor([0, 0, 1, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 1627.25 3240.0
# 2.5
# tensor([1, 1, 3, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 1629.25 3244.0
# 2.0
# tensor([0, 1, 0, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1631.75 3248.0
# 2.5
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 1634.25 3252.0
# 2.5
# tensor([1, 1, 1, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 1636.75 3256.0
# 2.5
# tensor([0, 0, 1, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 1639.25 3260.0
# 2.5
# tensor([3, 3, 3, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 1640.75 3264.0
# 1.5
# tensor([1, 0, 3, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 1642.75 3268.0
# 2.0
# tensor([1, 3, 1, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 1645.25 3272.0
# 2.5
# tensor([0, 1, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 1647.75 3276.0
# 2.5
# tensor([0, 0, 1, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 1649.25 3280.0
# 1.5
# tensor([0, 1, 1, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 1651.75 3284.0
# 2.5
# tensor([3, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 1654.25 3288.0
# 2.5
# tensor([3, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 1656.25 3292.0
# 2.0
# tensor([3, 0, 0, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1658.0 3296.0
# 1.75
# tensor([3, 3, 1, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 1660.0 3300.0
# 2.0
# tensor([1, 0, 0, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1662.5 3304.0
# 2.5
# tensor([1, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 1664.0 3308.0
# 1.5
# tensor([1, 0, 3, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 1665.5 3312.0
# 1.5
# tensor([3, 0, 1, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 1668.0 3316.0
# 2.5
# tensor([0, 0, 3, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 1669.5 3320.0
# 1.5
# tensor([0, 3, 1, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 1671.0 3324.0
# 1.5
# tensor([3, 0, 3, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 1673.0 3328.0
# 2.0
# tensor([1, 3, 3, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 1674.5 3332.0
# 1.5
# tensor([3, 0, 1, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 1677.0 3336.0
# 2.5
# tensor([1, 1, 1, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 1678.5 3340.0
# 1.5
# tensor([3, 1, 0, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1681.0 3344.0
# 2.5
# tensor([3, 1, 3, 3], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 1682.5 3348.0
# 1.5
# tensor([1, 3, 0, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1685.0 3352.0
# 2.5
# tensor([3, 3, 0, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1687.5 3356.0
# 2.5
# tensor([3, 3, 3, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 1689.0 3360.0
# 1.5
# tensor([1, 0, 3, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 1690.5 3364.0
# 1.5
# tensor([1, 0, 0, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1692.0 3368.0
# 1.5
# tensor([0, 3, 0, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1694.0 3372.0
# 2.0
# tensor([3, 0, 0, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1696.0 3376.0
# 2.0
# tensor([0, 1, 1, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 1698.0 3380.0
# 2.0
# tensor([3, 3, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 1700.5 3384.0
# 2.5
# tensor([0, 0, 0, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1702.5 3388.0
# 2.0
# tensor([1, 3, 1, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 1704.0 3392.0
# 1.5
# tensor([0, 0, 1, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 1705.5 3396.0
# 1.5
# tensor([3, 0, 0, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1707.0 3400.0
# 1.5
# tensor([0, 1, 0, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 1708.5 3404.0
# 1.5
# tensor([3, 1, 0, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 1710.5 3408.0
# 2.0
# tensor([1, 0, 1, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 1710.75 3409.0
# 0.25
# tensor([3], device='cuda:0')
# tensor([[3]], device='cuda:0')
# Current epoch: 16
# correct_t: 2.5 4.0
# 2.5
# tensor([3, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 5.0 8.0
# 2.5
# tensor([1, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 7.5 12.0
# 2.5
# tensor([0, 0, 3, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-941635a29259> in <module>
#      23     running_loss = 0.0
#      24     print('Current epoch:',epoch)
# ---> 25     for i, data in enumerate(dataloaders['train'], 0):
#      26         # get the inputs
#      27         inputs, labels = data
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in <listcomp>(.0)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# <ipython-input-3-d0310cb80709> in __getitem__(self, index)
#      35     def __getitem__(self, index):
#      36         fn, label = self.imgs[index]
# ---> 37         img = self.loader(fn)
#      38         img = img[256+128:768-128,256+128:768-128,:]#crop the cernter part of the image
#      39         if self.transform is not None:
#
# <ipython-input-3-d0310cb80709> in default_loader(path)
#       7 def default_loader(path):
#       8     data1 = np.load(path)
# ----> 9     data1 = np.log(data1)
#      10     return data1
#      11
#
# KeyboardInterrupt:

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
#         images, labels = data
#         outputs = net(images)
#         _, predicted = torch.max(outputs.data, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()
        
        images, labels = data
        images = images.type(torch.FloatTensor)
        images = images.cuda()
        labels = labels.type(torch.FloatTensor)
        labels = labels.cuda()
        outputs = net(images)
                
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        labels = labels.long()
        #print(total ,'   ', correct)
        correct += (predicted == labels).sum().item()
       

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-b42065b4b0fb> in <module>
#       2 total = 0
#       3 with torch.no_grad():
# ----> 4     for data in testloader:
#       5 #         images, labels = data
#       6 #         outputs = net(images)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in <listcomp>(.0)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# <ipython-input-3-d0310cb80709> in __getitem__(self, index)
#      35     def __getitem__(self, index):
#      36         fn, label = self.imgs[index]
# ---> 37         img = self.loader(fn)
#      38         img = img[256+128:768-128,256+128:768-128,:]#crop the cernter part of the image
#      39         if self.transform is not None:
#
# <ipython-input-3-d0310cb80709> in default_loader(path)
#       6 """
#       7 def default_loader(path):
# ----> 8     data1 = np.load(path)
#       9     data1 = np.log(data1)
#      10     return data1
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     438             else:
#     439                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 440                                          pickle_kwargs=pickle_kwargs)
#     441         else:
#     442             # Try a pickle
#
# ~\Anaconda3\lib\site-packages\numpy\lib\format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     702         if isfileobj(fp):
#     703             # We can use the fast fromfile() function.
# --> 704             array = numpy.fromfile(fp, dtype=dtype, count=count)
#     705         else:
#     706             # This is not a real file. We have to read it the
#
# KeyboardInterrupt:

# %%
epc = np.linspace(0,epoch,epoch)
plt.plot(epc, loss_mat[0:epoch])
plt.title("Epoch Vs Training Loss")
plt.xlabel("epoch") #
plt.ylabel("Loss") #

plt.show()

plt.plot(epc, loss_V[0:epoch])
plt.title("Epoch Vs Validation Loss")
plt.xlabel("epoch") #
plt.ylabel("Loss") #

plt.show()

# %%
print(correct)
print(total_T)
print(running_loss)
print(labels.view(labels.size(1), -1)[0])
print(predicted)
loss = criterion(outputs, labels.view(labels.size(1), -1)[0])
print(criterion(outputs, labels.view(labels.size(1), -1)[0]))
# Out:
# 0.0
# 20.0
# 5.871628165245056
# tensor([1, 1, 3, 3], device='cuda:0')
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor(1.8919, device='cuda:0', grad_fn=<NllLossBackward>)

# %% [markdown]
# # Save and load the network

# %%
torch.save(net.state_dict(),'E:\\Starring-at-the-Night-Sky\\16epc.pkl')

# %%
torch.load('E:\\Starring-at-the-Night-Sky\\16epc.pkl')

# %% [markdown]
# # Test

# %%
class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(30, 32, 5, stride=1, padding=2)
        self.conv1_bn = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(2, stride=2)
        self.conv2 = nn.Conv2d(32, 64, 3, stride=1, padding=1)
        self.conv2_bn = nn.BatchNorm2d(64)
        self.pool2 = nn.MaxPool2d(2, stride=2)
        self.fc1 = nn.Linear(262144, 1024)
        self.fc2 = nn.Linear(1024, 256)
        self.fc3 = nn.Linear(256, 4)

    def forward(self, x):
        #x = self.pool(F.relu(self.conv1(x)))
        #x = self.pool(F.relu(self.conv2(x)))
        #x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.conv1(x))
        x = self.conv1_bn(x)
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.conv2_bn(x)
        x = self.pool2(x)
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        return x

net = Net()

use_gpu = torch.cuda.is_available()  # 
if use_gpu:
    print('Use CUDA')
    net = net.cuda()
#    
import torch.optim as optim


#criterion =nn.BCELoss()

#criterion =nn.NLLLoss(weight=None, size_average=None, ignore_index=-100, reduce=None, reduction='elementwise_mean')

#m= nn.Sigmoid()
#criterion = nn.NLLLoss()
#criterion=nn.BCECriterion()


criterion = nn.CrossEntropyLoss()
#optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
optimizer = optim.Adam(net.parameters(), lr = 0.001, betas=(0.9, 0.999))
epc = 30
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
accuracy_T = np.zeros(epc)
accuracy = np.zeros(epc)
j = 0
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
trainloader = dataloaders['train']
testloader = dataloaders['val']
EPOCH = 135   #total epoches
pre_epoch = 0  # epoches existed
LR = 0.1
# Out:
# Use CUDA

# %%
epc = 100
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
accuracy_T = np.zeros(epc)
accuracy = np.zeros(epc)
j = 0
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
trainloader = dataloaders['train']
testloader = dataloaders['val']
EPOCH = 135   #total epoches
pre_epoch = 0  # epoches existed
LR = 0.1       
for epoch in range(epc):  # loop over the dataset multiple times
    correct = 0.0
    total = 0.0
    running_loss = 0.0
    running_loss_V = 0.0
    correct_T = 0.0
    total_T = 0.0
    j = 0
    running_loss = 0.0
    for i, data in enumerate(dataloaders['train'], 0):
        # get the inputs
        inputs, labels = data
        if j==0:
            plt.matshow(np.log(inputs[0,0,:,:]))
        j+=1

print('Finished Training')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-36e5564ad59b> in <module>
#      21     j = 0
#      22     running_loss = 0.0
# ---> 23     for i, data in enumerate(dataloaders['train'], 0):
#      24         # get the inputs
#      25         inputs, labels = data
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in <listcomp>(.0)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# <ipython-input-3-d0310cb80709> in __getitem__(self, index)
#      35     def __getitem__(self, index):
#      36         fn, label = self.imgs[index]
# ---> 37         img = self.loader(fn)
#      38         img = img[256+128:768-128,256+128:768-128,:]#crop the cernter part of the image
#      39         if self.transform is not None:
#
# <ipython-input-3-d0310cb80709> in default_loader(path)
#       6 """
#       7 def default_loader(path):
# ----> 8     data1 = np.load(path)
#       9     data1 = np.log(data1)
#      10     return data1
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     438             else:
#     439                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 440                                          pickle_kwargs=pickle_kwargs)
#     441         else:
#     442             # Try a pickle
#
# ~\Anaconda3\lib\site-packages\numpy\lib\format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     702         if isfileobj(fp):
#     703             # We can use the fast fromfile() function.
# --> 704             array = numpy.fromfile(fp, dtype=dtype, count=count)
#     705         else:
#     706             # This is not a real file. We have to read it the
#
# KeyboardInterrupt:
