# %%
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from PIL import Image
from torch.optim import lr_scheduler
import copy
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np
import torch.optim as optim
import random
import torch.nn as nn
import torch.nn.functional as F
import pprint, pickle
from torchvision import datasets, models, transforms
import time
import torch
import torchvision
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
from torchvision.datasets import DatasetFolder
from PIL import Image
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms
import time
import os
import copy
import numpy as np
import skimage.measure

# %%
def npy_loader(path):
    sample = torch.from_numpy(np.load(path))
    return sample
def get_round_pixel(data):
    center_x= (10+120)
    center_y=(9+120)
    radius_outer = 120/(np.sqrt(2))
    radius_inner=120 /2
    x_len = 256
    y_len = 256
    out = np.zeros((x_len,y_len,30))
    for i in range(x_len):
        for j in range(y_len):
            if ((center_x-i)**2 + (center_y-j)**2<=radius_outer**2):
                out[i,j,:] = data[i,j,:]
    #print(out.shape)
    #print(out[int(center_x-radius_outer):int(center_x+radius_outer),int(center_y-radius_outer):int(center_y+radius_outer),:].shape)
    out1 = out[int(center_x-radius_outer):int(center_x+radius_outer),int(center_y-radius_outer):int(center_y+radius_outer),:]
    return out1
class npyLoader(DatasetFolder):
    def __init__(self, txt, transform=None, target_transform=None, loader=npy_loader):
        fh = open(txt, 'r')
        imgs = []
        for line in fh:
            line = line.strip('\n')
            line = line.rstrip()
            words = line.split()
            if str(words[1]) == "i":
                label = 0
            elif str(words[1]) == "o":
                label = 1
            elif str(words[1]) == "u":
                label = 2
            else:
                label = 3
            imgs.append((words[0],str(label)))

        self.imgs = imgs
        self.transform = transform
        self.target_transform = target_transform
        self.loader = loader

# %%
"""
i:166 (* 8)
o:82  (*16)
p:1330
u:83  (*16)
""" 
def default_loader(path):
    data1 = np.load(path)
    data1 = np.log(data1)
    return data1

class MyDataset(Dataset):
    def __init__(self, txt,loader=default_loader, transform=None, target_transform=None):
        fh = open(txt, 'r')
        imgs = []
        for line in fh:
            line = line.strip('\n')
            line = line.rstrip()
            words = line.split()
            if str(words[1]) == "i":
                label = 0
            elif str(words[1]) == "o":
                label = 1
            elif str(words[1]) == "u":
                label = 2
            else:
                label = 3
           
            imgs.append((words[0],str(label)))
            
        self.imgs = imgs
        self.transform = transform
        self.target_transform = target_transform
        self.loader = loader

    def __getitem__(self, index):
        fn, label = self.imgs[index]
        img = self.loader(fn)
        img = skimage.measure.block_reduce(img, (4,4,1), np.max)
#         print(img.shape)
        img = get_round_pixel(img)
#         img = img[256+128:768-128,256+128:768-128,:]#crop the cernter part of the image
        if self.transform is not None:
            img = self.transform(img)
        img=img.swapaxes(1,2)
        img=img.swapaxes(0,1)
        img = torch.from_numpy(img)
        label = list(map(int, label))
        label = np.asarray(label)
        label = label.astype(int)
        label = torch.from_numpy(label)
        return img,label

    def __len__(self):
        return len(self.imgs)

# %%
data_transforms = {
    'train': transforms.Compose([
#         transforms.CenterCrop(224),
#         transforms.RandomHorizontalFlip(),
#         transforms.ToTensor(),
#         transforms.Normalize(mean = [0.5]*30, std = [0.5]*30)
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
#         transforms.ToTensor(),
#         transforms.Normalize(mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5))
#         transforms.Resize(256),
#         transforms.CenterCrop(224),
#         transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
#         transforms.ToTensor(),
#         transforms.Normalize(mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5))
#         transforms.Resize(256),
#         transforms.CenterCrop(224),
#         transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}
valset = MyDataset(txt='E:\\TMT_SITE_RAID\\TMT_DATA_2\\T2-Armazones\\valset\\list.txt',transform=data_transforms['train'])
trainset = MyDataset(txt='E:\\TMT_SITE_RAID\\TMT_DATA_2\\T2-Armazones\\Test_data\\list1.txt',transform=data_transforms['train'])
testset = MyDataset(txt='E:\\TMT_SITE_RAID\\TMT_DATA_2\\T2-Armazones\\Testset\\list.txt',  transform=data_transforms['test'])
train_size = 0.70
val_size = 0.30
num_train = len(trainset)
indices = list(range(num_train))
random.shuffle(indices)
num_val = len(valset)
valid_idx = list(range(num_val))
num_test = len(testset)
test_idx = list(range(num_test))
split = int(np.floor(train_size * num_train))
split_val = int(np.floor(val_size * num_train))

# train_idx, valid_idx, test_idx = indices[:split], indices[split:split_val+split], indices[split_val+split:]
# train_idx, valid_idx = indices[:split], indices[split:]

image_datasets={'train': MyDataset(txt='E:\\TMT_SITE_RAID\\TMT_DATA_2\\T2-Armazones\\Test_Data\\list1.txt',  transform=data_transforms['train']),
                'val': MyDataset(txt='E:\\TMT_SITE_RAID\\TMT_DATA_2\\T2-Armazones\\valset\\list.txt',  transform=data_transforms['val']),
                'test': MyDataset(txt='E:\\TMT_SITE_RAID\\TMT_DATA_2\\T2-Armazones\\Testset\\list.txt',  transform=data_transforms['test']),
                }
train_sampler = torch.utils.data.SubsetRandomSampler(indices)
val_sampler = torch.utils.data.SubsetRandomSampler(valid_idx)
test_sampler = torch.utils.data.SubsetRandomSampler(test_idx)

dataloaders = {
        'train': torch.utils.data.DataLoader(trainset, batch_size=4,sampler = train_sampler,
                                          shuffle=False, num_workers=0),
        'val': torch.utils.data.DataLoader(valset, batch_size=4,sampler = val_sampler,
                                          shuffle=False, num_workers=0),
        'test': torch.utils.data.DataLoader(testset, batch_size=1,sampler = test_sampler,
                                          shuffle=False, num_workers=0),
                }
dataset_sizes = {
        'train':num_train,
        'val': num_val,
        'test': num_test
				    }

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
inputs, classes = next(iter(dataloaders['train']))
# plt.matshow(np.log(inputs[3,0,:,:]))
plt.matshow(inputs[3,0,:,:])
# print(inputs.shape)
# print(classes)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    def __init__(self, inchannel, outchannel, stride=1):
        super(ResidualBlock, self).__init__()
        self.left = nn.Sequential(
            nn.Conv2d(inchannel, outchannel, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(outchannel),
            nn.ReLU(inplace=True),
            nn.Conv2d(outchannel, outchannel, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(outchannel)
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or inchannel != outchannel:
            self.shortcut = nn.Sequential(
                nn.Conv2d(inchannel, outchannel, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(outchannel)
            )

    def forward(self, x):
        out = self.left(x)
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet(nn.Module):
    ###
    def __init__(self, ResidualBlock, num_classes=4):
        super(ResNet, self).__init__()
        self.inchannel = 64
        #change the channel to 30
        self.conv1 = nn.Sequential(
            nn.Conv2d(30, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
        )
        self.layer1 = self.make_layer(ResidualBlock, 64,  2, stride=1)
        self.layer2 = self.make_layer(ResidualBlock, 128, 2, stride=2)
        self.layer3 = self.make_layer(ResidualBlock, 256, 2, stride=2)
        self.layer4 = self.make_layer(ResidualBlock, 512, 2, stride=2)
        self.fc = nn.Linear(12800, num_classes)

    def make_layer(self, block, channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)   #strides=[1,1]
        layers = []
        for stride in strides:
            layers.append(block(self.inchannel, channels, stride))
            self.inchannel = channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out


def ResNet18():

    return ResNet(ResidualBlock)
net = ResNet18()
use_gpu = torch.cuda.is_available()  # 
if use_gpu:
    net = net.cuda()
epc = 100
criterion = nn.CrossEntropyLoss()
#optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
optimizer = optim.Adam(net.parameters(), lr = 0.0001, betas=(0.9, 0.999))
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
trainloader = dataloaders['train']
valloader = dataloaders['val']
EPOCH = 135   #total epoches
pre_epoch = 0  # epoches existed
LR = 0.1

# %%
epc = 10
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
accuracy_T = np.zeros(epc)
accuracy = np.zeros(epc)
j = 0
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
trainloader = dataloaders['train']
valloader = dataloaders['val']
testloader = dataloaders['test']
# EPOCH = 135   #total epoches
pre_epoch = 0  # epoches existed
LR = 0.1       
n_val_samples = num_val
for epoch in range(epc):  # loop over the dataset multiple times
    correct = 0.0
    total = 0.0
    running_loss = 0.0
    running_loss_V = 0.0
    correct_T = 0.0
    total_T = 0.0
    
    running_loss = 0.0
    print('Current epoch:',epoch)
    for i, data in enumerate(dataloaders['train'], 0):
        # get the inputs
        inputs, labels = data
        inputs = inputs.type(torch.FloatTensor)
        inputs = inputs.cuda()
        labels = labels.type(torch.FloatTensor)
        labels = labels.cuda()
#         print(inputs.size())
#         inputs, labels = inputs.cuda(), labels.cuda()
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward + backward + optimize
        outputs = net(inputs)
#         print(outputs)
        _, predicted = torch.max(outputs.data, 1)
#         labels = labels.view(-1,4)

        labels = labels.long()
        
        correct_T += (predicted == labels.view(labels.size(1), -1)[0]).sum().item()
        
        total_T += labels.size(0)
        accuracy_T[epoch] = 100 * correct_T / total_T
        print('correct_t:',correct_T,total_T)
        print(predicted)
        print(labels)
        loss = criterion(outputs, labels.view(labels.size(1), -1)[0])
        loss.backward()
        optimizer.step()
        
        # print statistics
        running_loss += loss.item()
        if i % 200== 199:    # print every 200 mini-batches
            print('[%d, %5d] training loss: %.3f training accuracy: %.2f' %
                  (epoch + 1, i + 1, running_loss /  200, accuracy_T[epoch]))
            for data in valloader:
                images, labels = data
                images = images.type(torch.FloatTensor)
                images = images.cuda()
                labels = labels.type(torch.FloatTensor)
                labels = labels.cuda()
                
              
                outputs = net(images)
                
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                labels = labels.long()
                #print(total ,'   ', correct)
                correct += (predicted == labels.view(labels.size(1), -1)[0]).sum().item()
                accuracy[epoch] = 100 * correct / total
                loss = criterion(outputs, labels.view(labels.size(1), -1)[0])
                running_loss_V += loss.item()
            loss_mat[epoch] = running_loss / 200
            loss_V[epoch] = running_loss_V / (n_val_samples/4)
            print('Validation loss: %.3f validation accuracy: %.2f' %
                (loss_V[epoch] , accuracy[epoch]))
            running_loss = 0.0
            running_loss_V = 0.0
            correct = 0
            total = 0

print('Finished Training')
# Out:
# Current epoch: 0
# correct_t: 0.0 4.0
# tensor([3, 2, 3, 3], device='cuda:0')
# tensor([[2],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 2.0 8.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [2],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 3.0 12.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[2],
#         [2],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 6.0 16.0
# tensor([2, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 8.0 20.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 8.0 24.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 8.0 28.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[2],
#         [3],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 9.0 32.0
# tensor([2, 1, 3, 2], device='cuda:0')
# tensor([[1],
#         [2],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 11.0 36.0
# tensor([3, 2, 2, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 12.0 40.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [2],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 14.0 44.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[0],
#         [0],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 15.0 48.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[3],
#         [1],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 17.0 52.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[2],
#         [0],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 18.0 56.0
# tensor([0, 3, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 19.0 60.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 19.0 64.0
# tensor([3, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 19.0 68.0
# tensor([0, 3, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 19.0 72.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [2],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 19.0 76.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 19.0 80.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[2],
#         [2],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 21.0 84.0
# tensor([0, 2, 2, 2], device='cuda:0')
# tensor([[3],
#         [2],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 22.0 88.0
# tensor([0, 2, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 24.0 92.0
# tensor([0, 2, 2, 2], device='cuda:0')
# tensor([[1],
#         [2],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 26.0 96.0
# tensor([2, 0, 2, 2], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 27.0 100.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[0],
#         [2],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 28.0 104.0
# tensor([0, 0, 0, 2], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 28.0 108.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[2],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 29.0 112.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [2],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 31.0 116.0
# tensor([1, 2, 0, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 34.0 120.0
# tensor([1, 2, 1, 1], device='cuda:0')
# tensor([[0],
#         [2],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 36.0 124.0
# tensor([1, 1, 1, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 38.0 128.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[2],
#         [1],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 39.0 132.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 39.0 136.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 41.0 140.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 43.0 144.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 45.0 148.0
# tensor([1, 1, 1, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 46.0 152.0
# tensor([1, 1, 1, 3], device='cuda:0')
# tensor([[2],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 46.0 156.0
# tensor([3, 3, 3, 2], device='cuda:0')
# tensor([[1],
#         [0],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 49.0 160.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 50.0 164.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[2],
#         [0],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 50.0 168.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[2],
#         [2],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 52.0 172.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 54.0 176.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 57.0 180.0
# tensor([0, 2, 0, 0], device='cuda:0')
# tensor([[0],
#         [2],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 58.0 184.0
# tensor([2, 2, 2, 0], device='cuda:0')
# tensor([[2],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 59.0 188.0
# tensor([2, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 62.0 192.0
# tensor([2, 2, 0, 0], device='cuda:0')
# tensor([[2],
#         [2],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 62.0 196.0
# tensor([2, 2, 0, 2], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 65.0 200.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[2],
#         [2],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 66.0 204.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 68.0 208.0
# tensor([2, 1, 1, 2], device='cuda:0')
# tensor([[2],
#         [2],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 70.0 212.0
# tensor([1, 1, 1, 2], device='cuda:0')
# tensor([[1],
#         [2],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 71.0 216.0
# tensor([2, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 72.0 220.0
# tensor([1, 1, 2, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 76.0 224.0
# tensor([1, 1, 1, 2], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 76.0 228.0
# tensor([1, 1, 1, 2], device='cuda:0')
# tensor([[3],
#         [2],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 78.0 232.0
# tensor([1, 2, 1, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 80.0 236.0
# tensor([1, 2, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 82.0 240.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[2],
#         [2],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 84.0 244.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 85.0 248.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 87.0 252.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 88.0 256.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[2],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 88.0 260.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 90.0 264.0
# tensor([1, 1, 3, 1], device='cuda:0')
# tensor([[0],
#         [2],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 93.0 268.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 93.0 272.0
# tensor([3, 3, 0, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 95.0 276.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[2],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 95.0 280.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[2],
#         [2],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 96.0 284.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[2],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 96.0 288.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 98.0 292.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 100.0 296.0
# tensor([2, 3, 2, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 102.0 300.0
# tensor([3, 2, 3, 2], device='cuda:0')
# tensor([[2],
#         [2],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 104.0 304.0
# tensor([0, 2, 3, 2], device='cuda:0')
# tensor([[1],
#         [2],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 104.0 308.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 106.0 312.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[3],
#         [2],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 107.0 316.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 108.0 320.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[3],
#         [1],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 110.0 324.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[0],
#         [0],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 112.0 328.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[0],
#         [2],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 114.0 332.0
# tensor([2, 1, 2, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 116.0 336.0
# tensor([2, 1, 2, 2], device='cuda:0')
# tensor([[2],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 116.0 340.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 117.0 344.0
# tensor([0, 0, 1, 2], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 120.0 348.0
# tensor([1, 0, 1, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 123.0 352.0
# tensor([0, 1, 2, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 123.0 356.0
# tensor([1, 0, 0, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 125.0 360.0
# tensor([0, 0, 1, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 125.0 364.0
# tensor([1, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 126.0 368.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 126.0 372.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 126.0 376.0
# tensor([3, 0, 3, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 126.0 380.0
# tensor([3, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 128.0 384.0
# tensor([0, 0, 3, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 130.0 388.0
# tensor([0, 3, 0, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 132.0 392.0
# tensor([3, 1, 3, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 133.0 396.0
# tensor([3, 2, 3, 3], device='cuda:0')
# tensor([[2],
#         [2],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 134.0 400.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 135.0 404.0
# tensor([3, 3, 0, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 138.0 408.0
# tensor([2, 3, 0, 3], device='cuda:0')
# tensor([[2],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 139.0 412.0
# tensor([3, 1, 0, 1], device='cuda:0')
# tensor([[2],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 140.0 416.0
# tensor([3, 2, 2, 3], device='cuda:0')
# tensor([[1],
#         [2],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 142.0 420.0
# tensor([3, 2, 2, 0], device='cuda:0')
# tensor([[0],
#         [2],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 145.0 424.0
# tensor([3, 2, 0, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 146.0 428.0
# tensor([2, 3, 3, 3], device='cuda:0')
# tensor([[2],
#         [2],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 148.0 432.0
# tensor([0, 2, 3, 2], device='cuda:0')
# tensor([[0],
#         [2],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 149.0 436.0
# tensor([3, 1, 2, 3], device='cuda:0')
# tensor([[0],
#         [3],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 150.0 440.0
# tensor([2, 3, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 151.0 444.0
# tensor([2, 3, 2, 2], device='cuda:0')
# tensor([[2],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 152.0 448.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[1],
#         [2],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 154.0 452.0
# tensor([0, 0, 2, 2], device='cuda:0')
# tensor([[0],
#         [1],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 156.0 456.0
# tensor([2, 0, 0, 2], device='cuda:0')
# tensor([[2],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 159.0 460.0
# tensor([2, 2, 2, 0], device='cuda:0')
# tensor([[2],
#         [2],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 160.0 464.0
# tensor([0, 2, 2, 0], device='cuda:0')
# tensor([[3],
#         [2],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 161.0 468.0
# tensor([2, 2, 0, 2], device='cuda:0')
# tensor([[2],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 163.0 472.0
# tensor([0, 2, 2, 0], device='cuda:0')
# tensor([[0],
#         [2],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 165.0 476.0
# tensor([0, 2, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 166.0 480.0
# tensor([2, 0, 1, 1], device='cuda:0')
# tensor([[2],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 169.0 484.0
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 170.0 488.0
# tensor([1, 2, 0, 2], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 172.0 492.0
# tensor([2, 1, 1, 1], device='cuda:0')
# tensor([[2],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 173.0 496.0
# tensor([1, 2, 1, 1], device='cuda:0')
# tensor([[2],
#         [2],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 175.0 500.0
# tensor([1, 1, 1, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 176.0 504.0
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 177.0 508.0
# tensor([2, 1, 2, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 177.0 512.0
# tensor([1, 2, 2, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 178.0 516.0
# tensor([1, 2, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 180.0 520.0
# tensor([1, 1, 1, 2], device='cuda:0')
# tensor([[1],
#         [2],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 182.0 524.0
# tensor([1, 1, 2, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 182.0 528.0
# tensor([1, 3, 0, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 184.0 532.0
# tensor([3, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 186.0 536.0
# tensor([3, 3, 3, 2], device='cuda:0')
# tensor([[3],
#         [2],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 188.0 540.0
# tensor([3, 2, 2, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 189.0 544.0
# tensor([3, 2, 3, 3], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 190.0 548.0
# tensor([3, 3, 2, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 191.0 552.0
# tensor([3, 3, 2, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 194.0 556.0
# tensor([3, 3, 2, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 195.0 560.0
# tensor([3, 3, 2, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 197.0 564.0
# tensor([3, 3, 2, 2], device='cuda:0')
# tensor([[3],
#         [1],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 199.0 568.0
# tensor([2, 3, 2, 3], device='cuda:0')
# tensor([[2],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 202.0 572.0
# tensor([3, 1, 3, 3], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 202.0 576.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 203.0 580.0
# tensor([3, 3, 2, 3], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 204.0 584.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 206.0 588.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 207.0 592.0
# tensor([3, 3, 2, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 209.0 596.0
# tensor([0, 3, 0, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 211.0 600.0
# tensor([3, 0, 0, 2], device='cuda:0')
# tensor([[2],
#         [1],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 213.0 604.0
# tensor([0, 0, 0, 2], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 214.0 608.0
# tensor([0, 0, 1, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 216.0 612.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 217.0 616.0
# tensor([0, 0, 0, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 218.0 620.0
# tensor([0, 0, 1, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 221.0 624.0
# tensor([2, 0, 0, 0], device='cuda:0')
# tensor([[2],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 224.0 628.0
# tensor([0, 2, 0, 0], device='cuda:0')
# tensor([[3],
#         [2],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 226.0 632.0
# tensor([0, 0, 0, 2], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 228.0 636.0
# tensor([0, 0, 0, 1], device='cuda:0')
# tensor([[2],
#         [0],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 228.0 640.0
# tensor([0, 0, 3, 3], device='cuda:0')
# tensor([[1],
#         [2],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 230.0 644.0
# tensor([0, 0, 3, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 231.0 648.0
# tensor([0, 0, 2, 0], device='cuda:0')
# tensor([[3],
#         [2],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 231.0 652.0
# tensor([3, 0, 3, 2], device='cuda:0')
# tensor([[2],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 233.0 656.0
# tensor([2, 0, 2, 0], device='cuda:0')
# tensor([[2],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 235.0 660.0
# tensor([3, 0, 0, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 235.0 664.0
# tensor([2, 0, 3, 2], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 237.0 668.0
# tensor([3, 3, 2, 2], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 241.0 672.0
# tensor([2, 0, 3, 2], device='cuda:0')
# tensor([[2],
#         [0],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 243.0 676.0
# tensor([3, 3, 2, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 244.0 680.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 245.0 684.0
# tensor([2, 2, 1, 2], device='cuda:0')
# tensor([[3],
#         [2],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 248.0 688.0
# tensor([2, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 249.0 692.0
# tensor([3, 3, 2, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 250.0 696.0
# tensor([3, 2, 2, 3], device='cuda:0')
# tensor([[0],
#         [3],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 250.0 700.0
# tensor([2, 2, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 251.0 704.0
# tensor([2, 3, 3, 3], device='cuda:0')
# tensor([[2],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 255.0 708.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 257.0 712.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 259.0 716.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 259.0 720.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[2],
#         [1],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 260.0 724.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[2],
#         [2],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 261.0 728.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 263.0 732.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 263.0 736.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [2],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 265.0 740.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 267.0 744.0
# tensor([0, 3, 3, 3], device='cuda:0')
# tensor([[2],
#         [3],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 268.0 748.0
# tensor([3, 3, 2, 3], device='cuda:0')
# tensor([[0],
#         [2],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 269.0 752.0
# tensor([0, 3, 2, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 270.0 756.0
# tensor([3, 0, 3, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 272.0 760.0
# tensor([3, 0, 3, 0], device='cuda:0')
# tensor([[2],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 274.0 764.0
# tensor([0, 2, 2, 0], device='cuda:0')
# tensor([[0],
#         [2],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 275.0 768.0
# tensor([2, 2, 0, 2], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 277.0 772.0
# tensor([0, 2, 2, 0], device='cuda:0')
# tensor([[1],
#         [2],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 278.0 776.0
# tensor([2, 0, 2, 2], device='cuda:0')
# tensor([[2],
#         [2],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 279.0 780.0
# tensor([0, 0, 2, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 280.0 784.0
# tensor([2, 2, 2, 0], device='cuda:0')
# tensor([[2],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 282.0 788.0
# tensor([1, 1, 2, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 282.0 792.0
# tensor([1, 2, 1, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 285.0 796.0
# tensor([1, 2, 2, 1], device='cuda:0')
# tensor([[1],
#         [2],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 285.0 800.0
# tensor([2, 1, 2, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# [1,   200] training loss: 1.401 training accuracy: 35.62
# Validation loss: 1.669 validation accuracy: 7.11
# correct_t: 287.0 804.0
# tensor([1, 2, 2, 1], device='cuda:0')
# tensor([[1],
#         [2],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 287.0 808.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 291.0 812.0
# tensor([1, 2, 1, 1], device='cuda:0')
# tensor([[1],
#         [2],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 293.0 816.0
# tensor([3, 2, 1, 2], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 295.0 820.0
# tensor([3, 3, 2, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 295.0 824.0
# tensor([2, 3, 1, 0], device='cuda:0')
# tensor([[1],
#         [2],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 297.0 828.0
# tensor([3, 1, 3, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 298.0 832.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 299.0 836.0
# tensor([3, 3, 3, 2], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 300.0 840.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 303.0 844.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [2],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 303.0 848.0
# tensor([3, 2, 3, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 305.0 852.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 306.0 856.0
# tensor([3, 3, 2, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 307.0 860.0
# tensor([3, 3, 3, 2], device='cuda:0')
# tensor([[2],
#         [2],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 308.0 864.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 310.0 868.0
# tensor([3, 2, 3, 3], device='cuda:0')
# tensor([[0],
#         [2],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 311.0 872.0
# tensor([3, 1, 2, 2], device='cuda:0')
# tensor([[2],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 315.0 876.0
# tensor([3, 3, 0, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 316.0 880.0
# tensor([3, 0, 1, 2], device='cuda:0')
# tensor([[2],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 317.0 884.0
# tensor([0, 3, 3, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 319.0 888.0
# tensor([2, 2, 2, 3], device='cuda:0')
# tensor([[1],
#         [1],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 321.0 892.0
# tensor([1, 2, 3, 3], device='cuda:0')
# tensor([[1],
#         [2],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 324.0 896.0
# tensor([1, 1, 1, 2], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 327.0 900.0
# tensor([1, 2, 1, 1], device='cuda:0')
# tensor([[1],
#         [2],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 328.0 904.0
# tensor([2, 1, 2, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 329.0 908.0
# tensor([1, 1, 1, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 332.0 912.0
# tensor([2, 1, 1, 1], device='cuda:0')
# tensor([[2],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 333.0 916.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 334.0 920.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 335.0 924.0
# tensor([2, 1, 1, 3], device='cuda:0')
# tensor([[2],
#         [2],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 338.0 928.0
# tensor([2, 1, 1, 2], device='cuda:0')
# tensor([[2],
#         [0],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 339.0 932.0
# tensor([0, 1, 3, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 340.0 936.0
# tensor([2, 2, 1, 0], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 342.0 940.0
# tensor([0, 1, 2, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 344.0 944.0
# tensor([1, 1, 3, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 346.0 948.0
# tensor([3, 2, 3, 0], device='cuda:0')
# tensor([[3],
#         [2],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 348.0 952.0
# tensor([3, 0, 1, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 351.0 956.0
# tensor([3, 3, 1, 2], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 351.0 960.0
# tensor([0, 3, 0, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 353.0 964.0
# tensor([0, 1, 3, 3], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 354.0 968.0
# tensor([3, 1, 3, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 355.0 972.0
# tensor([3, 0, 3, 2], device='cuda:0')
# tensor([[2],
#         [2],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 356.0 976.0
# tensor([2, 3, 2, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 356.0 980.0
# tensor([3, 3, 3, 0], device='cuda:0')
# tensor([[2],
#         [1],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 358.0 984.0
# tensor([3, 3, 2, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 359.0 988.0
# tensor([2, 3, 0, 3], device='cuda:0')
# tensor([[2],
#         [0],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 362.0 992.0
# tensor([2, 3, 2, 2], device='cuda:0')
# tensor([[2],
#         [0],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 364.0 996.0
# tensor([3, 1, 2, 2], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 365.0 1000.0
# tensor([1, 0, 2, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 368.0 1004.0
# tensor([0, 0, 2, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 371.0 1008.0
# tensor([3, 2, 2, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 374.0 1012.0
# tensor([2, 2, 2, 1], device='cuda:0')
# tensor([[2],
#         [2],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 376.0 1016.0
# tensor([1, 1, 2, 2], device='cuda:0')
# tensor([[1],
#         [3],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 377.0 1020.0
# tensor([0, 2, 2, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 379.0 1024.0
# tensor([0, 1, 2, 2], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 381.0 1028.0
# tensor([1, 1, 0, 2], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 384.0 1032.0
# tensor([0, 0, 2, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 386.0 1036.0
# tensor([2, 0, 2, 0], device='cuda:0')
# tensor([[2],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 389.0 1040.0
# tensor([0, 0, 2, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 389.0 1044.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 390.0 1048.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 394.0 1052.0
# tensor([0, 2, 1, 2], device='cuda:0')
# tensor([[0],
#         [2],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 395.0 1056.0
# tensor([1, 0, 1, 0], device='cuda:0')
# tensor([[3],
#         [2],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 396.0 1060.0
# tensor([1, 2, 0, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 398.0 1064.0
# tensor([0, 3, 1, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 399.0 1068.0
# tensor([0, 0, 1, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 401.0 1072.0
# tensor([1, 3, 1, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 402.0 1076.0
# tensor([0, 2, 1, 2], device='cuda:0')
# tensor([[3],
#         [2],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 405.0 1080.0
# tensor([3, 1, 2, 2], device='cuda:0')
# tensor([[0],
#         [1],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 407.0 1084.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 410.0 1088.0
# tensor([2, 3, 1, 2], device='cuda:0')
# tensor([[2],
#         [1],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 413.0 1092.0
# tensor([2, 3, 2, 2], device='cuda:0')
# tensor([[2],
#         [1],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 414.0 1096.0
# tensor([3, 2, 3, 3], device='cuda:0')
# tensor([[0],
#         [2],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 417.0 1100.0
# tensor([3, 2, 1, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 419.0 1104.0
# tensor([3, 3, 0, 2], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 422.0 1108.0
# tensor([0, 1, 1, 2], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 423.0 1112.0
# tensor([3, 1, 2, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 427.0 1116.0
# tensor([2, 1, 0, 1], device='cuda:0')
# tensor([[2],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 428.0 1120.0
# tensor([0, 1, 2, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 431.0 1124.0
# tensor([2, 0, 2, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 433.0 1128.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 437.0 1132.0
# tensor([0, 0, 2, 2], device='cuda:0')
# tensor([[0],
#         [0],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 438.0 1136.0
# tensor([1, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 439.0 1140.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 440.0 1144.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 441.0 1148.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 443.0 1152.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 445.0 1156.0
# tensor([0, 2, 0, 0], device='cuda:0')
# tensor([[2],
#         [2],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 448.0 1160.0
# tensor([3, 2, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 450.0 1164.0
# tensor([2, 2, 0, 3], device='cuda:0')
# tensor([[2],
#         [0],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 451.0 1168.0
# tensor([0, 0, 2, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 453.0 1172.0
# tensor([2, 0, 0, 2], device='cuda:0')
# tensor([[2],
#         [1],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 455.0 1176.0
# tensor([2, 2, 3, 0], device='cuda:0')
# tensor([[2],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 458.0 1180.0
# tensor([1, 3, 3, 2], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 460.0 1184.0
# tensor([3, 0, 2, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 462.0 1188.0
# tensor([3, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 465.0 1192.0
# tensor([1, 1, 2, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 465.0 1196.0
# tensor([1, 1, 3, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 468.0 1200.0
# tensor([2, 1, 2, 1], device='cuda:0')
# tensor([[2],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 471.0 1204.0
# tensor([1, 2, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 472.0 1208.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 472.0 1212.0
# tensor([1, 3, 3, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 474.0 1216.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 474.0 1220.0
# tensor([3, 2, 1, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 476.0 1224.0
# tensor([3, 1, 1, 2], device='cuda:0')
# tensor([[1],
#         [2],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 480.0 1228.0
# tensor([2, 2, 2, 3], device='cuda:0')
# tensor([[2],
#         [2],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 483.0 1232.0
# tensor([1, 1, 0, 2], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 486.0 1236.0
# tensor([0, 1, 2, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 488.0 1240.0
# tensor([2, 1, 2, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 490.0 1244.0
# tensor([2, 0, 2, 2], device='cuda:0')
# tensor([[2],
#         [1],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 492.0 1248.0
# tensor([2, 0, 2, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 494.0 1252.0
# tensor([1, 2, 0, 3], device='cuda:0')
# tensor([[1],
#         [2],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 496.0 1256.0
# tensor([2, 3, 3, 2], device='cuda:0')
# tensor([[2],
#         [0],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 499.0 1260.0
# tensor([1, 3, 2, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 500.0 1264.0
# tensor([3, 3, 3, 2], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 503.0 1268.0
# tensor([2, 3, 3, 2], device='cuda:0')
# tensor([[2],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 504.0 1272.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 507.0 1276.0
# tensor([3, 3, 3, 2], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 508.0 1280.0
# tensor([3, 0, 3, 2], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 508.0 1284.0
# tensor([2, 0, 1, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 509.0 1288.0
# tensor([2, 1, 2, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 512.0 1292.0
# tensor([3, 1, 2, 2], device='cuda:0')
# tensor([[2],
#         [1],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 514.0 1296.0
# tensor([1, 0, 3, 2], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 515.0 1300.0
# tensor([1, 2, 0, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 516.0 1304.0
# tensor([1, 1, 1, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 520.0 1308.0
# tensor([1, 0, 1, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 524.0 1312.0
# tensor([0, 1, 0, 2], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 528.0 1316.0
# tensor([0, 2, 1, 2], device='cuda:0')
# tensor([[0],
#         [2],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 532.0 1320.0
# tensor([0, 2, 1, 2], device='cuda:0')
# tensor([[0],
#         [2],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 535.0 1324.0
# tensor([0, 2, 2, 0], device='cuda:0')
# tensor([[0],
#         [2],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 537.0 1328.0
# tensor([2, 0, 0, 0], device='cuda:0')
# tensor([[2],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 540.0 1332.0
# tensor([0, 2, 0, 2], device='cuda:0')
# tensor([[0],
#         [2],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 542.0 1336.0
# tensor([0, 0, 1, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 545.0 1340.0
# tensor([0, 2, 1, 0], device='cuda:0')
# tensor([[0],
#         [2],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 548.0 1344.0
# tensor([1, 2, 2, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 551.0 1348.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 553.0 1352.0
# tensor([1, 2, 1, 1], device='cuda:0')
# tensor([[2],
#         [2],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 554.0 1356.0
# tensor([1, 0, 3, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 556.0 1360.0
# tensor([1, 1, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 557.0 1364.0
# tensor([3, 3, 1, 2], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 559.0 1368.0
# tensor([1, 1, 1, 2], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 560.0 1372.0
# tensor([0, 1, 1, 2], device='cuda:0')
# tensor([[3],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 561.0 1376.0
# tensor([1, 1, 2, 2], device='cuda:0')
# tensor([[3],
#         [2],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 562.0 1380.0
# tensor([3, 1, 3, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 562.0 1384.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[0],
#         [2],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 564.0 1388.0
# tensor([3, 0, 3, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 567.0 1392.0
# tensor([2, 0, 1, 1], device='cuda:0')
# tensor([[2],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 570.0 1396.0
# tensor([0, 0, 1, 2], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 573.0 1400.0
# tensor([0, 1, 2, 2], device='cuda:0')
# tensor([[0],
#         [1],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 576.0 1404.0
# tensor([0, 1, 0, 2], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 577.0 1408.0
# tensor([0, 1, 0, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 577.0 1412.0
# tensor([0, 1, 2, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 578.0 1416.0
# tensor([2, 1, 0, 1], device='cuda:0')
# tensor([[2],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 581.0 1420.0
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 583.0 1424.0
# tensor([0, 2, 2, 1], device='cuda:0')
# tensor([[1],
#         [2],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 584.0 1428.0
# tensor([1, 3, 1, 3], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 584.0 1432.0
# tensor([3, 1, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 586.0 1436.0
# tensor([1, 3, 0, 2], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 589.0 1440.0
# tensor([3, 3, 0, 2], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 592.0 1444.0
# tensor([3, 0, 3, 3], device='cuda:0')
# tensor([[3],
#         [2],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 593.0 1448.0
# tensor([3, 2, 3, 3], device='cuda:0')
# tensor([[2],
#         [2],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 594.0 1452.0
# tensor([3, 3, 3, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 595.0 1456.0
# tensor([3, 2, 3, 2], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 598.0 1460.0
# tensor([3, 3, 2, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 598.0 1464.0
# ...
# tensor([2, 3, 1, 1], device='cuda:0')
# tensor([[2],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 2486.0 2728.0
# tensor([1, 1, 2, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 2490.0 2732.0
# tensor([2, 0, 1, 1], device='cuda:0')
# tensor([[2],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 2494.0 2736.0
# tensor([3, 3, 3, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 2497.0 2740.0
# tensor([0, 1, 3, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 2501.0 2744.0
# tensor([0, 2, 3, 1], device='cuda:0')
# tensor([[0],
#         [2],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 2505.0 2748.0
# tensor([0, 0, 0, 2], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 2508.0 2752.0
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 2512.0 2756.0
# tensor([0, 2, 0, 1], device='cuda:0')
# tensor([[0],
#         [2],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 2516.0 2760.0
# tensor([2, 3, 1, 1], device='cuda:0')
# tensor([[2],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 2520.0 2764.0
# tensor([3, 1, 1, 3], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 2524.0 2768.0
# tensor([3, 2, 1, 3], device='cuda:0')
# tensor([[3],
#         [2],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 2528.0 2772.0
# tensor([1, 1, 1, 0], device='cuda:0')
# tensor([[1],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 2532.0 2776.0
# tensor([3, 0, 2, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 2535.0 2780.0
# tensor([3, 0, 0, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 2539.0 2784.0
# tensor([0, 2, 0, 3], device='cuda:0')
# tensor([[0],
#         [2],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 2543.0 2788.0
# tensor([1, 3, 1, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 2547.0 2792.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[2],
#         [2],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 2550.0 2796.0
# tensor([3, 1, 1, 2], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 2554.0 2800.0
# tensor([1, 3, 3, 2], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 2557.0 2804.0
# tensor([0, 2, 3, 3], device='cuda:0')
# tensor([[3],
#         [2],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 2560.0 2808.0
# tensor([3, 3, 3, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 2564.0 2812.0
# tensor([1, 0, 2, 3], device='cuda:0')
# tensor([[1],
#         [0],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 2567.0 2816.0
# tensor([0, 0, 0, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 2571.0 2820.0
# tensor([2, 2, 0, 3], device='cuda:0')
# tensor([[2],
#         [2],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 2575.0 2824.0
# tensor([0, 0, 1, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 2579.0 2828.0
# tensor([0, 2, 0, 2], device='cuda:0')
# tensor([[0],
#         [2],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 2583.0 2832.0
# tensor([2, 2, 3, 2], device='cuda:0')
# tensor([[2],
#         [2],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 2587.0 2836.0
# tensor([3, 2, 2, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2591.0 2840.0
# tensor([3, 1, 2, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 2595.0 2844.0
# tensor([0, 3, 1, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 2599.0 2848.0
# tensor([1, 3, 3, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 2602.0 2852.0
# tensor([2, 0, 1, 2], device='cuda:0')
# tensor([[2],
#         [0],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 2605.0 2856.0
# tensor([0, 1, 3, 2], device='cuda:0')
# tensor([[0],
#         [1],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 2609.0 2860.0
# tensor([2, 0, 1, 2], device='cuda:0')
# tensor([[2],
#         [0],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 2613.0 2864.0
# tensor([0, 3, 0, 1], device='cuda:0')
# tensor([[0],
#         [3],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 2617.0 2868.0
# tensor([2, 1, 3, 0], device='cuda:0')
# tensor([[2],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 2621.0 2872.0
# tensor([0, 1, 2, 1], device='cuda:0')
# tensor([[0],
#         [1],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2625.0 2876.0
# tensor([2, 1, 1, 1], device='cuda:0')
# tensor([[2],
#         [1],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 2628.0 2880.0
# tensor([2, 2, 3, 2], device='cuda:0')
# tensor([[2],
#         [2],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 2632.0 2884.0
# tensor([2, 0, 3, 2], device='cuda:0')
# tensor([[2],
#         [0],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 2636.0 2888.0
# tensor([1, 2, 3, 0], device='cuda:0')
# tensor([[1],
#         [2],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 2639.0 2892.0
# tensor([3, 3, 3, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 2643.0 2896.0
# tensor([1, 3, 1, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 2647.0 2900.0
# tensor([2, 1, 1, 2], device='cuda:0')
# tensor([[2],
#         [1],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 2651.0 2904.0
# tensor([0, 2, 0, 1], device='cuda:0')
# tensor([[0],
#         [2],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 2655.0 2908.0
# tensor([3, 3, 0, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 2659.0 2912.0
# tensor([3, 1, 0, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 2662.0 2916.0
# tensor([2, 0, 0, 0], device='cuda:0')
# tensor([[2],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 2666.0 2920.0
# tensor([0, 0, 3, 2], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 2669.0 2924.0
# tensor([2, 0, 2, 0], device='cuda:0')
# tensor([[2],
#         [0],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 2673.0 2928.0
# tensor([1, 3, 2, 1], device='cuda:0')
# tensor([[1],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2676.0 2932.0
# tensor([2, 0, 2, 0], device='cuda:0')
# tensor([[2],
#         [0],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 2679.0 2936.0
# tensor([2, 3, 3, 2], device='cuda:0')
# tensor([[2],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 2682.0 2940.0
# tensor([3, 1, 3, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 2686.0 2944.0
# tensor([0, 0, 3, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [3],
#         [3]], device='cuda:0')
# correct_t: 2690.0 2948.0
# tensor([3, 2, 1, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 2694.0 2952.0
# tensor([2, 2, 1, 2], device='cuda:0')
# tensor([[2],
#         [2],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 2698.0 2956.0
# tensor([0, 0, 2, 2], device='cuda:0')
# tensor([[0],
#         [0],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 2702.0 2960.0
# tensor([3, 3, 2, 1], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2706.0 2964.0
# tensor([2, 3, 0, 0], device='cuda:0')
# tensor([[2],
#         [3],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 2709.0 2968.0
# tensor([1, 3, 2, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2712.0 2972.0
# tensor([2, 1, 3, 0], device='cuda:0')
# tensor([[2],
#         [1],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 2714.0 2976.0
# tensor([3, 2, 0, 1], device='cuda:0')
# tensor([[0],
#         [2],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 2717.0 2980.0
# tensor([1, 2, 3, 2], device='cuda:0')
# tensor([[1],
#         [2],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 2719.0 2984.0
# tensor([2, 1, 2, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 2723.0 2988.0
# tensor([2, 0, 1, 2], device='cuda:0')
# tensor([[2],
#         [0],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 2726.0 2992.0
# tensor([0, 3, 0, 2], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 2730.0 2996.0
# tensor([2, 1, 2, 3], device='cuda:0')
# tensor([[2],
#         [1],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 2734.0 3000.0
# tensor([0, 0, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 2738.0 3004.0
# tensor([2, 2, 2, 1], device='cuda:0')
# tensor([[2],
#         [2],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2742.0 3008.0
# tensor([1, 1, 0, 1], device='cuda:0')
# tensor([[1],
#         [1],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 2746.0 3012.0
# tensor([3, 2, 1, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 2749.0 3016.0
# tensor([3, 2, 0, 0], device='cuda:0')
# tensor([[3],
#         [2],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 2753.0 3020.0
# tensor([2, 1, 2, 1], device='cuda:0')
# tensor([[2],
#         [1],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2756.0 3024.0
# tensor([0, 0, 2, 0], device='cuda:0')
# tensor([[0],
#         [0],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2760.0 3028.0
# tensor([0, 1, 1, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 2764.0 3032.0
# tensor([1, 2, 0, 0], device='cuda:0')
# tensor([[1],
#         [2],
#         [0],
#         [0]], device='cuda:0')
# correct_t: 2768.0 3036.0
# tensor([1, 0, 2, 1], device='cuda:0')
# tensor([[1],
#         [0],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2772.0 3040.0
# tensor([0, 1, 1, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 2775.0 3044.0
# tensor([0, 1, 0, 0], device='cuda:0')
# tensor([[0],
#         [1],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 2779.0 3048.0
# tensor([3, 1, 1, 2], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 2783.0 3052.0
# tensor([2, 3, 2, 1], device='cuda:0')
# tensor([[2],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2787.0 3056.0
# tensor([0, 2, 0, 3], device='cuda:0')
# tensor([[0],
#         [2],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 2791.0 3060.0
# tensor([1, 3, 1, 3], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 2795.0 3064.0
# tensor([2, 2, 0, 3], device='cuda:0')
# tensor([[2],
#         [2],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 2798.0 3068.0
# tensor([3, 1, 2, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 2802.0 3072.0
# tensor([0, 0, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 2806.0 3076.0
# tensor([2, 0, 2, 2], device='cuda:0')
# tensor([[2],
#         [0],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 2810.0 3080.0
# tensor([0, 2, 2, 3], device='cuda:0')
# tensor([[0],
#         [2],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 2814.0 3084.0
# tensor([3, 0, 1, 0], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 2818.0 3088.0
# tensor([0, 0, 1, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [1],
#         [1]], device='cuda:0')
# correct_t: 2822.0 3092.0
# tensor([0, 2, 2, 1], device='cuda:0')
# tensor([[0],
#         [2],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2825.0 3096.0
# tensor([0, 0, 0, 1], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 2829.0 3100.0
# tensor([2, 3, 1, 2], device='cuda:0')
# tensor([[2],
#         [3],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 2833.0 3104.0
# tensor([0, 2, 2, 1], device='cuda:0')
# tensor([[0],
#         [2],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2837.0 3108.0
# tensor([2, 1, 3, 1], device='cuda:0')
# tensor([[2],
#         [1],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 2840.0 3112.0
# tensor([2, 1, 0, 2], device='cuda:0')
# tensor([[2],
#         [3],
#         [0],
#         [2]], device='cuda:0')
# correct_t: 2844.0 3116.0
# tensor([3, 3, 2, 3], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [3]], device='cuda:0')
# correct_t: 2848.0 3120.0
# tensor([3, 0, 0, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 2852.0 3124.0
# tensor([0, 1, 2, 2], device='cuda:0')
# tensor([[0],
#         [1],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 2856.0 3128.0
# tensor([3, 2, 0, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 2860.0 3132.0
# tensor([0, 0, 0, 3], device='cuda:0')
# tensor([[0],
#         [0],
#         [0],
#         [3]], device='cuda:0')
# correct_t: 2864.0 3136.0
# tensor([2, 3, 2, 1], device='cuda:0')
# tensor([[2],
#         [3],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2868.0 3140.0
# tensor([3, 0, 3, 1], device='cuda:0')
# tensor([[3],
#         [0],
#         [3],
#         [1]], device='cuda:0')
# correct_t: 2872.0 3144.0
# tensor([2, 3, 3, 2], device='cuda:0')
# tensor([[2],
#         [3],
#         [3],
#         [2]], device='cuda:0')
# correct_t: 2875.0 3148.0
# tensor([0, 3, 2, 2], device='cuda:0')
# tensor([[3],
#         [3],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 2878.0 3152.0
# tensor([3, 3, 2, 0], device='cuda:0')
# tensor([[0],
#         [3],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 2882.0 3156.0
# tensor([3, 2, 0, 1], device='cuda:0')
# tensor([[3],
#         [2],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 2885.0 3160.0
# tensor([2, 0, 3, 2], device='cuda:0')
# tensor([[2],
#         [0],
#         [1],
#         [2]], device='cuda:0')
# correct_t: 2888.0 3164.0
# tensor([0, 1, 2, 3], device='cuda:0')
# tensor([[0],
#         [1],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2892.0 3168.0
# tensor([1, 2, 2, 1], device='cuda:0')
# tensor([[1],
#         [2],
#         [2],
#         [1]], device='cuda:0')
# correct_t: 2896.0 3172.0
# tensor([1, 2, 2, 0], device='cuda:0')
# tensor([[1],
#         [2],
#         [2],
#         [0]], device='cuda:0')
# correct_t: 2900.0 3176.0
# tensor([1, 0, 3, 0], device='cuda:0')
# tensor([[1],
#         [0],
#         [3],
#         [0]], device='cuda:0')
# correct_t: 2904.0 3180.0
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[2],
#         [2],
#         [2],
#         [2]], device='cuda:0')
# correct_t: 2908.0 3184.0
# tensor([2, 0, 0, 1], device='cuda:0')
# tensor([[2],
#         [0],
#         [0],
#         [1]], device='cuda:0')
# correct_t: 2912.0 3188.0
# tensor([3, 1, 1, 0], device='cuda:0')
# tensor([[3],
#         [1],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 2916.0 3192.0
# tensor([1, 3, 1, 0], device='cuda:0')
# tensor([[1],
#         [3],
#         [1],
#         [0]], device='cuda:0')
# correct_t: 2919.0 3196.0
# tensor([1, 0, 1, 3], device='cuda:0')
# tensor([[3],
#         [0],
#         [1],
#         [3]], device='cuda:0')
# correct_t: 2923.0 3200.0
# tensor([2, 0, 2, 0], device='cuda:0')
# tensor([[2],
#         [0],
#         [2],
#         [0]], device='cuda:0')
# [3,   800] training loss: 0.191 training accuracy: 91.34

# %%
print(predicted)
print(labels)
print()
print(predicted == labels.view(labels.size(1), -1)[0])
# Out:
# tensor([2, 2, 2, 2], device='cuda:0')
# tensor([[2],
#         [0],
#         [0],
#         [1]], device='cuda:0')
#
# tensor([1, 0, 0, 0], device='cuda:0', dtype=torch.uint8)

# %%
correct = 0
total = 0
crt = [0,0,0,0]
total_mat = [0,0,0,0]
with torch.no_grad():
    for data in dataloaders['test']:
#         images, labels = data
#         outputs = net(images)
#         _, predicted = torch.max(outputs.data, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()
        
        images, labels = data
        images = images.type(torch.FloatTensor)
        images = images.cuda()
        labels = labels.type(torch.FloatTensor)
        labels = labels.cuda()
        outputs = net(images)
                
        _, predicted = torch.max(outputs.data, 1)
        print(labels, predicted,"labels and predicted")
        total += 1
        labels = labels.long()
        total_mat[labels] += 1
        if (predicted == labels.view(labels.size(1), -1)[0]).sum().item()==1:
            crt[labels]+=1
        
        correct += (predicted == labels.view(labels.size(1), -1)[0]).sum().item()
        print(total ,'   ', correct)
       

print('Accuracy of the network on the test images: %d %%' % (
    100 * correct / total))
# Out:
# tensor([[2.]], device='cuda:0') tensor([3], device='cuda:0') labels and predicted
# 1     0
# tensor([[3.]], device='cuda:0') tensor([2], device='cuda:0') labels and predicted
# 2     0
# tensor([[0.]], device='cuda:0') tensor([0], device='cuda:0') labels and predicted
# 3     1
# tensor([[0.]], device='cuda:0') tensor([0], device='cuda:0') labels and predicted
# 4     2
# tensor([[3.]], device='cuda:0') tensor([1], device='cuda:0') labels and predicted
# 5     2
# tensor([[3.]], device='cuda:0') tensor([3], device='cuda:0') labels and predicted
# 6     3
# tensor([[3.]], device='cuda:0') tensor([0], device='cuda:0') labels and predicted
# 7     3
# tensor([[3.]], device='cuda:0') tensor([3], device='cuda:0') labels and predicted
# 8     4
# tensor([[3.]], device='cuda:0') tensor([3], device='cuda:0') labels and predicted
# 9     5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-84bda3b68e4b> in <module>
#       4 total_mat = [0,0,0,0]
#       5 with torch.no_grad():
# ----> 6     for data in dataloaders['test']:
#       7 #         images, labels = data
#       8 #         outputs = net(images)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in <listcomp>(.0)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# <ipython-input-68-165e55aec28f> in __getitem__(self, index)
#      37         fn, label = self.imgs[index]
#      38         img = self.loader(fn)
# ---> 39         img = skimage.measure.block_reduce(img, (4,4,1), np.max)
#      40 #         img = img[256+128:768-128,256+128:768-128,:]#crop the cernter part of the image
#      41         if self.transform is not None:
#
# ~\Anaconda3\lib\site-packages\skimage\measure\block.py in block_reduce(image, block_size, func, cval)
#      70
#      71     image = np.pad(image, pad_width=pad_width, mode='constant',
# ---> 72                    constant_values=cval)
#      73
#      74     out = view_as_blocks(image, block_size)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraypad.py in pad(array, pad_width, mode, **kwargs)
#    1237
#    1238     # If we get here, use new padding method
# -> 1239     newmat = narray.copy()
#    1240
#    1241     # API preserved, but completely new algorithm which pads by building the
#
# KeyboardInterrupt:

# %%
print(crt)
print(total_mat)
print(np.asarray(crt)/np.asarray(total_mat))
# Out:
# [5, 0, 1, 514]
# [74, 36, 59, 593]
# [0.06756757 0.         0.01694915 0.86677909]

# %%
epc = np.linspace(0,epoch,epoch)
plt.plot(epc, loss_mat[0:epoch])
plt.title("Epoch Vs Training Loss")
plt.xlabel("epoch") #
plt.ylabel("Loss") #

plt.show()

plt.plot(epc, loss_V[0:epoch])
plt.title("Epoch Vs Validation Loss")
plt.xlabel("epoch") #
plt.ylabel("Loss") #

plt.show()

# %%
epc = np.linspace(0,epoch,epoch)
plt.plot(epc, accuracy_T[0:epoch])
plt.title("Epoch Vs Training Accuracy")
plt.xlabel("epoch") #
plt.ylabel("Loss") #

plt.show()

plt.plot(epc, accuracy[0:epoch])
plt.title("Epoch Vs Validation Accuracy")
plt.xlabel("epoch") #
plt.ylabel("Loss") #

plt.show()

# %% [markdown]
# ### Testing

# %%
print(loss_mat[:epoch])
print(loss_V[:epoch])
# Out:
# [1.09411376 1.08886511 1.0462627  0.98059638 0.68227106 0.49907035
#  0.33403772 0.26549406 0.21624511 0.16484554 0.08384116 0.09853118
#  0.07038137 0.12713481 0.04569868 0.03079484]
# [0.71089773 1.09136727 0.91295599 1.0220887  0.30848949 0.29591233
#  0.16888583 0.39076482 0.10478241 0.03285191 0.07364065 0.16654263
#  0.01859543 0.08875581 0.0066546  0.00863669]

# %%
print(correct)
print(total_T)
print(running_loss)
print(labels.view(labels.size(1), -1)[0])
print(predicted)
loss = criterion(outputs, labels.view(labels.size(1), -1)[0])
print(criterion(outputs, labels.view(labels.size(1), -1)[0]))
# Out:
# 0.0
# 20.0
# 5.871628165245056
# tensor([1, 1, 3, 3], device='cuda:0')
# tensor([0, 0, 0, 0], device='cuda:0')
# tensor(1.8919, device='cuda:0', grad_fn=<NllLossBackward>)

# %% [markdown]
# # Save and load the network

# %%
# torch.save(net.state_dict(),'E:\\Starring-at-the-Night-Sky\\16epc.pkl')

# %%
torch.save(net ,'E:\\Starring-at-the-Night-Sky\\11epc.pkl')
# Out:
# C:\Users\u5889098\Anaconda3\lib\site-packages\torch\serialization.py:256: UserWarning: Couldn't retrieve source code for container of type ResNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\u5889098\Anaconda3\lib\site-packages\torch\serialization.py:256: UserWarning: Couldn't retrieve source code for container of type ResidualBlock. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
torch.load('E:\\Starring-at-the-Night-Sky\\16epc.pkl')

# %% [markdown]
# # Test

# %%
class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(30, 32, 5, stride=1, padding=2)
        self.conv1_bn = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(2, stride=2)
        self.conv2 = nn.Conv2d(32, 64, 3, stride=1, padding=1)
        self.conv2_bn = nn.BatchNorm2d(64)
        self.pool2 = nn.MaxPool2d(2, stride=2)
        self.fc1 = nn.Linear(262144, 1024)
        self.fc2 = nn.Linear(1024, 256)
        self.fc3 = nn.Linear(256, 4)

    def forward(self, x):
        #x = self.pool(F.relu(self.conv1(x)))
        #x = self.pool(F.relu(self.conv2(x)))
        #x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.conv1(x))
        x = self.conv1_bn(x)
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.conv2_bn(x)
        x = self.pool2(x)
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        return x

net = Net()

use_gpu = torch.cuda.is_available()  # 
if use_gpu:
    print('Use CUDA')
    net = net.cuda()
#    
import torch.optim as optim


#criterion =nn.BCELoss()

#criterion =nn.NLLLoss(weight=None, size_average=None, ignore_index=-100, reduce=None, reduction='elementwise_mean')

#m= nn.Sigmoid()
#criterion = nn.NLLLoss()
#criterion=nn.BCECriterion()


criterion = nn.CrossEntropyLoss()
#optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
optimizer = optim.Adam(net.parameters(), lr = 0.001, betas=(0.9, 0.999))
epc = 30
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
accuracy_T = np.zeros(epc)
accuracy = np.zeros(epc)
j = 0
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
trainloader = dataloaders['train']
testloader = dataloaders['val']
EPOCH = 135   #total epoches
pre_epoch = 0  # epoches existed
LR = 0.1
# Out:
# Use CUDA

# %%
epc = 100
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
accuracy_T = np.zeros(epc)
accuracy = np.zeros(epc)
j = 0
loss_mat = np.zeros(epc)
loss_V = np.zeros(epc)
trainloader = dataloaders['train']
testloader = dataloaders['val']
EPOCH = 135   #total epoches
pre_epoch = 0  # epoches existed
LR = 0.1       
for epoch in range(epc):  # loop over the dataset multiple times
    correct = 0.0
    total = 0.0
    running_loss = 0.0
    running_loss_V = 0.0
    correct_T = 0.0
    total_T = 0.0
    j = 0
    running_loss = 0.0
    for i, data in enumerate(dataloaders['train'], 0):
        # get the inputs
        inputs, labels = data
        if j==0:
            plt.matshow(np.log(inputs[0,0,:,:]))
        j+=1

print('Finished Training')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-36e5564ad59b> in <module>
#      21     j = 0
#      22     running_loss = 0.0
# ---> 23     for i, data in enumerate(dataloaders['train'], 0):
#      24         # get the inputs
#      25         inputs, labels = data
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in <listcomp>(.0)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# <ipython-input-3-d0310cb80709> in __getitem__(self, index)
#      35     def __getitem__(self, index):
#      36         fn, label = self.imgs[index]
# ---> 37         img = self.loader(fn)
#      38         img = img[256+128:768-128,256+128:768-128,:]#crop the cernter part of the image
#      39         if self.transform is not None:
#
# <ipython-input-3-d0310cb80709> in default_loader(path)
#       6 """
#       7 def default_loader(path):
# ----> 8     data1 = np.load(path)
#       9     data1 = np.log(data1)
#      10     return data1
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     438             else:
#     439                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 440                                          pickle_kwargs=pickle_kwargs)
#     441         else:
#     442             # Try a pickle
#
# ~\Anaconda3\lib\site-packages\numpy\lib\format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     702         if isfileobj(fp):
#     703             # We can use the fast fromfile() function.
# --> 704             array = numpy.fromfile(fp, dtype=dtype, count=count)
#     705         else:
#     706             # This is not a real file. We have to read it the
#
# KeyboardInterrupt:

# %%
from torchviz import make_dot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-77-1054c009c1b5> in <module>
# ----> 1 from torchviz import make_dot
#
# ModuleNotFoundError: No module named 'torchviz'
